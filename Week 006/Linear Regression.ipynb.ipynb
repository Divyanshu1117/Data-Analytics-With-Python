# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import matplotlib as mpl
import statsmodels.formula.api as sm
from sklearn.linear_model import LinearRegression
from scipy import stats

# %%
tbl = pd.read_excel("regr.xlsx")
tbl.head()
# Out:
#    TV Ads  car Sold
# 0       1        14
# 1       3        24
# 2       2        18
# 3       1        17
# 4       3        27

# %%
import statsmodels.api as s

# %%
t = tbl['TV Ads']
c = tbl['car Sold']
t = s.add_constant(t)

# %%
model1 = s.OLS(c, t)
result1 = model1.fit()

# %%
print(result1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               car Sold   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.836
# Method:                 Least Squares   F-statistic:                     21.43
# Date:                Wed, 01 Apr 2026   Prob (F-statistic):             0.0190
# Time:                        20:04:02   Log-Likelihood:                -9.6687
# No. Observations:                   5   AIC:                             23.34
# Df Residuals:                       3   BIC:                             22.56
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         10.0000      2.366      4.226      0.024       2.469      17.531
# TV Ads         5.0000      1.080      4.629      0.019       1.563       8.437
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.214
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.674
# Skew:                           0.256   Prob(JB):                        0.714
# Kurtosis:                       1.276   Cond. No.                         6.33
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\vashi\anaconda3\Lib\site-packages\statsmodels\stats\stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "

# %%
sns.regplot(x='TV Ads', y='car Sold', data=tbl)
plt.show()

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy import stats
import statsmodels.formula.api as smf

# %%
data = pd.read_excel("chemitech.xlsx")

# %%
data
# Out:
#     A   B   C
# 0  58  58  48
# 1  64  69  57
# 2  55  71  59
# 3  66  64  47
# 4  67  68  49

# %%
data_r = pd.melt(data.reset_index(), id_vars=['index'], value_vars=['A', 'B', 'C'])
data_r.columns = ['index', 'treatments', 'value']

# %%
data_r
# Out:
#     index treatments  value
# 0       0          A     58
# 1       1          A     64
# 2       2          A     55
# 3       3          A     66
# 4       4          A     67
# 5       0          B     58
# 6       1          B     69
# 7       2          B     71
# 8       3          B     64
# 9       4          B     68
# 10      0          C     48
# 11      1          C     57
# 12      2          C     59
# 13      3          C     47
# 14      4          C     49

# %%
model = ols('value ~ C(treatments)', data=data_r).fit()
anova_table = sm.stats.anova_lm(model, typ=1)
anova_table
# Out:
#                  df  sum_sq     mean_sq         F    PR(>F)
# C(treatments)   2.0   520.0  260.000000  9.176471  0.003818
# Residual       12.0   340.0   28.333333       NaN       NaN

# %%
just_dummies = pd.get_dummies(data_r['treatments'])

# %%
just_dummies
# Out:
#         A      B      C
# 0    True  False  False
# 1    True  False  False
# 2    True  False  False
# 3    True  False  False
# 4    True  False  False
# 5   False   True  False
# 6   False   True  False
# 7   False   True  False
# 8   False   True  False
# 9   False   True  False
# 10  False  False   True
# 11  False  False   True
# 12  False  False   True
# 13  False  False   True
# 14  False  False   True

# %%
step_1 = pd.concat([data_r, just_dummies], axis=1)
step_1.drop(['treatments', 'C'], inplace=True, axis=1)
step_1
# Out:
#     index  value      A      B
# 0       0     58   True  False
# 1       1     64   True  False
# 2       2     55   True  False
# 3       3     66   True  False
# 4       4     67   True  False
# 5       0     58  False   True
# 6       1     69  False   True
# 7       2     71  False   True
# 8       3     64  False   True
# 9       4     68  False   True
# 10      0     48  False  False
# 11      1     57  False  False
# 12      2     59  False  False
# 13      3     47  False  False
# 14      4     49  False  False

# %%
# result = smf.OLS(step_1['value'], sm.add_constant(step_1[['A', 'B']])).fit()
# print(result.summary())

result = smf.ols('value ~ A + B', data=step_1).fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.605
# Model:                            OLS   Adj. R-squared:                  0.539
# Method:                 Least Squares   F-statistic:                     9.176
# Date:                Thu, 02 Apr 2026   Prob (F-statistic):            0.00382
# Time:                        20:47:34   Log-Likelihood:                -44.691
# No. Observations:                  15   AIC:                             95.38
# Df Residuals:                      12   BIC:                             97.51
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     52.0000      2.380     21.844      0.000      46.813      57.187
# A[T.True]     10.0000      3.367      2.970      0.012       2.665      17.335
# B[T.True]     14.0000      3.367      4.159      0.001       6.665      21.335
# ==============================================================================
# Omnibus:                        3.780   Durbin-Watson:                   2.550
# Prob(Omnibus):                  0.151   Jarque-Bera (JB):                1.311
# Skew:                          -0.196   Prob(JB):                        0.519
# Kurtosis:                       1.606   Cond. No.                         3.73
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model = ols('value ~ A + B', data=step_1).fit()
anova_table = sm.stats.anova_lm(model, typ=1)
anova_table
# Out:
#             df  sum_sq     mean_sq          F    PR(>F)
# A          1.0    30.0   30.000000   1.058824  0.323779
# B          1.0   490.0  490.000000  17.294118  0.001326
# Residual  12.0   340.0   28.333333        NaN       NaN

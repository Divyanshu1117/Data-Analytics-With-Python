# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:/Jupyter Notebook/Data_Analytics/Week 1/gapminder-FiveYearData.csv")

# %%
df

# %%
print(df.head())

# %%
print(df.shape)

# %%
print(df.columns)

# %%
print(df.dtypes)

# %%
print(df.info())

# %%
country_df = df['country']

# %%
print(country_df.head())

# %%
print(country_df.tail())

# %%
subset = df[['country','continent','year']]

# %%
print(subset.head())

# %%
print(subset.tail())

# %%
df.head()

# %%
df.loc[0]

# %%
df.loc[99]

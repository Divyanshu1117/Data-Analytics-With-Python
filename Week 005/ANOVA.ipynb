# %%
from scipy import stats

# %%
a = [4,3,2]

# %%
b = [2,4,6]

# %%
c = [2,1,3]

# %%
stats.f_oneway(a,b,c)
# Out:
# F_onewayResult(statistic=np.float64(1.5), pvalue=np.float64(0.29629629629629634))

# %%
import scipy
from scipy.spatial import distance

# %%
# Euclidean Distance
import numpy as np
a = [1, 2, 3]
b = [4, 5, 6]
dst = distance.euclidean(a,b)

# %%
dst
# Out:
# np.float64(5.196152422706632)

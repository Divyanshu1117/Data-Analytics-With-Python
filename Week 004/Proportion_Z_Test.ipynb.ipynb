# %%
from statsmodels.stats.proportion import proportions_ztest

# %%
count = 67

# %%
samplesize = 120

# %%
P = 0.5

# %%
proportions_ztest(count, samplesize, P)
# Out:
# (np.float64(1.286806739751111), np.float64(0.1981616572238455))

# %%
(1.286807739251111, 0.198161652223845)
# Out:
# (1.286807739251111, 0.198161652223845)

# %%
0.198161652223845 / 2
# Out:
# 0.0990808261119225

# %%
0.0990808261119225
# Out:
# 0.0990808261119225

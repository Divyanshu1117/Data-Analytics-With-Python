# %%
from scipy import stats
import numpy as np

# %%
x = [10, 12, 20, 21, 22, 24, 18, 15]
stats.ttest_1samp(x, 15)
# Out:
# TtestResult(statistic=np.float64(1.5623450931857947), pvalue=np.float64(0.16217875605928933), df=np.int64(7))

# %%
x = [13, 8, 10, 10, 8, 9, 10, 11, 6, 8, 12, 11, 11, 12, 10, 12, 7, 10, 11, 8]

# %%
stats.ttest_1samp(x, 10)
# Out:
# TtestResult(statistic=np.float64(-0.358433858548785), pvalue=np.float64(0.7239703579964251), df=np.int64(19))

# %%
0.7239703579964252 / 2
# Out:
# 0.3619851789982126

# %%
# One-Tailed Test
stats.t.cdf(-0.384, 19)
# Out:
# np.float64(0.3526210256679558)

# %%
stats.t.ppf(0.05, 19)
# Out:
# np.float64(-1.7291328115213687)

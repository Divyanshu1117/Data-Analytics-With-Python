# %%
from scipy import stats

# %%
stats.norm.cdf(1.96)
# Out:
# np.float64(0.9750021048517795)

# %%
# Finding P Value
stats.norm.cdf(-1.46)
# Out:
# np.float64(0.07214503696589378)

# %%
# Finding Z Value
stats.norm.ppf(0.1)
# Out:
# np.float64(-1.2815515655446004)

# %%
# p-Value Approach
1-stats.norm.cdf(1.75)
# Out:
# np.float64(0.040059156863817114)

# %%
1-stats.norm.cdf(2.29)
# Out:
# np.float64(0.011010658324411393)

# %%
stats.norm.ppf(0.95)
# Out:
# np.float64(1.6448536269514722)

# %%
1-stats.norm.cdf(1.09)
# Out:
# np.float64(0.1378565720320355)

# %%
1-stats.norm.cdf(2.74)
# Out:
# np.float64(0.003071959218650444)

# %%
(1 - stats.norm.cdf(2.74)) * 2
# Out:
# np.float64(0.006143918437300888)

# %%
stats.norm.ppf(0.015)
# Out:
# np.float64(-2.1700903775845606)

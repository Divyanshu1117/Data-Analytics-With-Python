# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_excel('Simmons.xls')

# %%
df
# Out:
#     Customer  Spending  Card  Coupon
# 0          1     2.291     1       0
# 1          2     3.215     1       0
# 2          3     2.135     1       0
# 3          4     3.924     0       0
# 4          5     2.528     1       0
# ..       ...       ...   ...     ...
# 95        96     3.318     0       0
# 96        97     2.421     1       0
# 97        98     6.073     0       0
# 98        99     2.630     1       0
# 99       100     3.411     0       1
#
# [100 rows x 4 columns]

# %%
plt.scatter(df.Spending, df.Coupon,marker = '+', color = 'red')

# %%
x = df[['Card', 'Spending']]
y = df['Coupon']

import statsmodels.api as sm
x1 = sm.add_constant(x)
logit_model = sm.Logit(y, x1)
result = logit_model.fit()
print(result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.604869
#          Iterations 5
#                          Results: Logit
# ================================================================
# Model:              Logit            Method:           MLE
# Dependent Variable: Coupon           Pseudo R-squared: 0.101
# Date:               2026-03-13 20:19 AIC:              126.9739
# No. Observations:   100              BIC:              134.7894
# Df Model:           2                Log-Likelihood:   -60.487
# Df Residuals:       97               LL-Null:          -67.301
# Converged:          1.0000           LLR p-value:      0.0010981
# No. Iterations:     5.0000           Scale:            1.0000
# -----------------------------------------------------------------
#               Coef.   Std.Err.     z     P>|z|    [0.025   0.975]
# -----------------------------------------------------------------
# const        -2.1464    0.5772  -3.7183  0.0002  -3.2778  -1.0150
# Card          1.0987    0.4447   2.4707  0.0135   0.2271   1.9703
# Spending      0.3416    0.1287   2.6551  0.0079   0.0894   0.5938
# ================================================================

# %%
import scipy
from scipy.stats import chi2

# %%
chi2.pdf(13.628, 2)
# Out:
# np.float64(0.000549145469075383)
